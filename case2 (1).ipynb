# %% [markdown]
# # Case Study 2 : Data Mining in Yelp Data

# %% [markdown]
# Please download the Yelp dataset in Case Study 2 in BrightSpace.
#
# **Here is an example of the data format:**
# ### Business Objects
#
# Business objects contain basic information about local businesses. The fields are as follows:
#
# ```json
# {
#   'type': 'business',
#   'business_id': (a unique identifier for this business),
#   'name': (the full business name),
#   'neighborhoods': (a list of neighborhood names, might be empty),
#   'full_address': (localized address),
#   'city': (city),
#   'state': (state),
#   'latitude': (latitude),
#   'longitude': (longitude),
#   'stars': (star rating, rounded to half-stars),
#   'review_count': (review count),
#   'photo_url': (photo url),
#   'categories': [(localized category names)]
#   'open': (is the business still open for business?),
#   'schools': (nearby universities),
#   'url': (yelp url)
# }
# ```
# ### Checkin Objects
# ```json
# {
#     'type': 'checkin',
#     'business_id': (encrypted business id),
#     'checkin_info': {
#         '0-0': (number of checkins from 00:00 to 01:00 on all Sundays),
#         '1-0': (number of checkins from 01:00 to 02:00 on all Sundays),
#         ...
#         '14-4': (number of checkins from 14:00 to 15:00 on all Thursdays),
#         ...
#         '23-6': (number of checkins from 23:00 to 00:00 on all Saturdays)
#     }, # if there was no checkin for a hour-day block it will not be in the dict
# }
# ```

# %% [markdown]
# # Problem: pick a data science problem that you plan to solve using Yelp Data
# * The problem should be important and interesting, which has a potential impact in some area.
# * The problem should be solvable using yelp data and data science solutions.
#
# Please briefly describe in the following cell: what problem are you trying to solve? why this problem is important and interesting?

# %% [markdown]
# What we are going to try to do is predict the amount of stars a restaurant will have given certain features that will be determined later on. This will be useful because it could allow restaurants to see what collection of factors will lead to them being well recieved. They can balance this knowledge out with cost to see how they can be profitable. This problem is important interesting because it can be used by thousands of small businesses across the nation. We are isolating restaurants do we can focus on one sector the the economy.

# %% [markdown]
# # Data Collection/Processing:

# %%
#----------------------------------------------
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary
import pandas as pd

# load the file data into a Pandas DataFrame
df = pd.read_json('yelp_academic_dataset_business.json', lines = True, nrows = 5000)
#we only take the first 5000 lines because the overall dataset is way too large for us to use on this machine
df
# Out:
#                  business_id                                name  \
# 0     Apn5Q_b6Nz61Tq4XzPdf9A                Minhas Micro Brewery
# 1     AjEbIBw6ZFfln7ePHha9PA                 CK'S BBQ & Catering
# 2     O8S5hYJ1SMc8fA4QBtVujA                       La Bastringue
# 3     bFzdJJ3wp3PZssNEsyU23g                     Geico Insurance
# 4     8USyCYqpScwiNEb58Bt6CA                       Action Engine
# ...                      ...                                 ...
# 4995  EGMBR4Quh2tggMkySIKG1g           American Eagle Outfitters
# 4996  ZQBUBnccfiCzQTrEwNy-xw  All American Dave's Fit Food Truck
# 4997  KxYpQHzuBlnAMmDlxrAoeA                 Long Creek Fish Fry
# 4998  ZeEKKLja4xeGuy2nApMpsw          Coney Island Fried Chicken
# 4999  SbS0cnxFStrlidtwek6b6w                                100℃
#
#                    neighborhood                         address       city  \
# 0                                             1314 44 Avenue NE    Calgary
# 1                                                                Henderson
# 2     Rosemont-La Petite-Patrie             1335 rue Beaubien E   Montréal
# 3                                               211 W Monroe St    Phoenix
# 4                                           2005 Alyth Place SE    Calgary
# ...                         ...                             ...        ...
# 4995                                        9617 N Metro Pkwy W    Phoenix
# 4996                                           4291 Polaris Ave  Las Vegas
# 4997                                       1031 Lower Dallas Rd     Dallas
# 4998                 Unionville                5261 Highway 7 E    Markham
# 4999                  Chinatown  5600 Spring Mountain Rd, Ste B  Las Vegas
#
#      state postal_code   latitude   longitude  stars  review_count  is_open  \
# 0       AB     T2E 6L6  51.091813 -114.031675    4.0            24        1
# 1       NV       89002  35.960734 -114.939821    4.5             3        0
# 2       QC     H2G 1K7  45.540503  -73.599300    4.0             5        0
# 3       AZ       85003  33.449999 -112.076979    1.5             8        1
# 4       AB     T2H 0N5  51.035591 -114.027366    2.0             4        1
# ...    ...         ...        ...         ...    ...           ...      ...
# 4995    AZ       85051  33.574974 -112.121034    4.0             3        0
# 4996    NV       89103  36.107558 -115.181217    4.5             9        1
# 4997    NC       28034  35.312525  -81.157819    4.0             4        1
# 4998    ON     L3P 1B8  43.866732  -79.283908    3.5             9        0
# 4999    NV       89146  36.126508 -115.218285    4.0            46        0
#
#                                              attributes  \
# 0     {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1     {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2     {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 3                                                  None
# 4                {'BusinessAcceptsCreditCards': 'True'}
# ...                                                 ...
# 4995             {'BusinessAcceptsCreditCards': 'True'}
# 4996  {'Alcohol': 'none', 'BikeParking': 'True', 'Bu...
# 4997                                               None
# 4998  {'Alcohol': 'none', 'Ambience': '{'romantic': ...
# 4999  {'Alcohol': 'none', 'Ambience': '{'romantic': ...
#
#                                              categories  \
# 0     Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1     Chicken Wings, Burgers, Caterers, Street Vendo...
# 2     Breakfast & Brunch, Restaurants, French, Sandw...
# 3                         Insurance, Financial Services
# 4     Home & Garden, Nurseries & Gardening, Shopping...
# ...                                                 ...
# 4995  Fashion, Shopping, Men's Clothing, Women's Clo...
# 4996  Restaurants, Food Trucks, Health & Medical, Gl...
# 4997                               Seafood, Restaurants
# 4998        Food, Restaurants, Fast Food, Chicken Wings
# 4999           Chinese, Taiwanese, Restaurants, Hot Pot
#
#                                                   hours
# 0     {'Monday': '8:30-17:0', 'Tuesday': '11:0-21:0'...
# 1     {'Friday': '17:0-23:0', 'Saturday': '17:0-23:0...
# 2     {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...
# 3                                                  None
# 4     {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...
# ...                                                 ...
# 4995                                               None
# 4996  {'Monday': '9:0-23:0', 'Tuesday': '9:0-23:0', ...
# 4997  {'Wednesday': '15:0-21:0', 'Thursday': '15:0-2...
# 4998  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 4999  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
#
# [5000 rows x 15 columns]

# %%
df2 = pd.read_json('yelp_academic_dataset_checkin.json', lines = True, nrows = 5000)
#we only take the first 5000 lines because the overall dataset is way too large for us to use on this machine
df2
# Out:
#                                            checkin_info     type  \
# 0     {'9-5': 1, '7-5': 1, '13-3': 1, '17-6': 1, '13...  checkin
# 1     {'16-2': 1, '22-5': 1, '9-5': 1, '9-4': 3, '15...  checkin
# 2     {'23-1': 1, '13-4': 1, '17-6': 1, '15-1': 1, '...  checkin
# 3                        {'5-5': 2, '5-1': 2, '8-2': 1}  checkin
# 4     {'15-1': 1, '13-3': 1, '16-0': 1, '9-3': 1, '1...  checkin
# ...                                                 ...      ...
# 4995  {'22-5': 3, '22-4': 2, '22-3': 1, '22-1': 2, '...  checkin
# 4996  {'22-6': 1, '22-4': 1, '22-2': 1, '22-1': 3, '...  checkin
# 4997  {'13-5': 1, '19-5': 1, '20-0': 1, '19-1': 1, '...  checkin
# 4998  {'9-1': 1, '9-0': 1, '9-2': 1, '13-2': 1, '15-...  checkin
# 4999  {'16-1': 1, '12-0': 1, '14-5': 1, '19-0': 1, '...  checkin
#
#                  business_id
# 0     cE27W9VPgO88Qxe4ol6y_g
# 1     mVHrayjG3uZ_RLHkLj-AMg
# 2     KayYbHCt-RkbGcPdGOThNg
# 3     b12U9TFESStdy7CsTtcOeg
# 4     QoDa50dc7g62xciFygXB9w
# ...                      ...
# 4995  OfNQed4MVoSyY31YJkJWqA
# 4996  b1d8nKDgizi3K8Jw6llksw
# 4997  FKlr2XmPA7G5MlMFpka1OQ
# 4998  0lgNM_dwPKTCn8ah_mnM5Q
# 4999  nzfTy-pnGeEgQdRW2CUriA
#
# [5000 rows x 3 columns]

# %% [markdown]
# # Data Exploration: Exploring the Yelp Dataset
#
# **(1) Finding the most popular business categories:**
# * print the top 10 most popular business categories in the dataset and their counts in a table (i.e., how many business objects in each category). Here we say a category is "popular" if there are many business objects in this category (such as 'restaurants').

# %%
dfc = df["categories"]

dfc2 = dfc.str.split(', ')
#now we have a list of each category rather than a string

everything_list = [] #will create a list with every value in category
everything_count = {}#will create a dictionary where the key is the value from category and the value is the number of times it is seen

# for loops to fill the list and dictionary with the correct information as stated above
for x in dfc2:
    if x is not None:
        for y in x:
            if y in everything_list:
                if y in everything_count:
                    everything_count[y] += 1
                else:
                    everything_count[y] = 1
            else:
                everything_list.append(y)
                everything_count[y] = 1

top_10 = {} #creates a top 10 list of which are the most seen categories in the whole dataframe
sorted_categories = sorted(everything_count.items(), key=lambda x: x[1], reverse=True)

for item in sorted_categories[:10]:
    key, value = item
    top_10[key] = value

print(top_10)
# Out:
# {'Restaurants': 1556, 'Shopping': 808, 'Food': 750, 'Home Services': 486, 'Beauty & Spas': 446, 'Health & Medical': 401, 'Local Services': 353, 'Automotive': 346, 'Nightlife': 330, 'Bars': 292}

# %% [markdown]
# **(2) Find the most popular business objects**
# * print the top 10 most popular business objects/IDs in the dataset and their counts (i.e., how many checkins in total for each business object).  Here we say a business object is "popular" if the business object attracts a large number of checkins from the users.

# %%
checkin_dict = df2.set_index('business_id')['checkin_info'].to_dict()
#creates a dictionary with the business ids as the keys and the checkin info as the valeus
total_checkins_by_business = {}

#adds up the amount of checkins each place has
for business_id, checkin_info in checkin_dict.items():
    total_checkins = sum(checkin_info.values())
    total_checkins_by_business[business_id] = total_checkins

#finds the top 10 places with the most checkins    
top_10pt2 = {}
sorted_checkins = sorted(total_checkins_by_business.items(), key=lambda x: x[1], reverse=True)

for item in sorted_checkins[:10]:
    key, value = item
    top_10pt2[key] = value

print(top_10pt2)
# Out:
# {'hW0Ne_HTHEAgGF1rAdmR-g': 68711, '3Q0QQPnHcJuX1DLCL9G9Cg': 29893, 'R8VwdLyvsp9iybNqRvm94g': 4631, 'sR9lSQiTuBg8zsIw9Zd-Dg': 4136, 'uFJwKlHL6HyHSJmORO8-5w': 3520, 'SDwYQ6eSu1htn8vHWv128g': 3469, 'L9UYbtAUOcfTgZFimehlXw': 3467, 'LzNJLEIo4gh-X_rmDkNkNg': 2656, 'AkOruz5CrCxUmXe1p_WoRg': 2510, 'XLqnjlLYt0_q_NG7l_BpMA': 2384}

# %% [markdown]
# **(3) Other explorations you would like to present**

# %%
df.describe(include='all')
# Out:
#                    business_id    name neighborhood address       city state  \
# count                     5000    5000         5000    5000       5000  5000
# unique                    5000    4617          239    4696        299    21
# top     Apn5Q_b6Nz61Tq4XzPdf9A  Subway                       Las Vegas    AZ
# freq                         1      27         3089     214        705  1368
# mean                       NaN     NaN          NaN     NaN        NaN   NaN
# std                        NaN     NaN          NaN     NaN        NaN   NaN
# min                        NaN     NaN          NaN     NaN        NaN   NaN
# 25%                        NaN     NaN          NaN     NaN        NaN   NaN
# 50%                        NaN     NaN          NaN     NaN        NaN   NaN
# 75%                        NaN     NaN          NaN     NaN        NaN   NaN
# max                        NaN     NaN          NaN     NaN        NaN   NaN
#
#        postal_code     latitude    longitude        stars  review_count  \
# count         5000  4999.000000  4999.000000  5000.000000   5000.000000
# unique        1733          NaN          NaN          NaN           NaN
# top          89119          NaN          NaN          NaN           NaN
# freq            69          NaN          NaN          NaN           NaN
# mean           NaN    39.012591   -96.091668     3.614100     28.600800
# std            NaN     5.196577    17.851947     1.022614     74.476404
# min            NaN   -34.513891  -180.000000     1.000000      3.000000
# 25%            NaN    33.671375  -112.249505     3.000000      4.000000
# 50%            NaN    36.241242   -89.376234     3.500000      8.000000
# 75%            NaN    43.649829   -79.704180     4.500000     23.000000
# max            NaN    85.051129   112.092039     5.000000   1565.000000
#
#             is_open                              attributes  \
# count   5000.000000                                    4288
# unique          NaN                                    2578
# top             NaN  {'BusinessAcceptsCreditCards': 'True'}
# freq            NaN                                     352
# mean       0.832200                                     NaN
# std        0.373726                                     NaN
# min        0.000000                                     NaN
# 25%        1.000000                                     NaN
# 50%        1.000000                                     NaN
# 75%        1.000000                                     NaN
# max        1.000000                                     NaN
#
#                 categories                                              hours
# count                 4990                                               3768
# unique                3517                                               2368
# top     Coffee & Tea, Food  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# freq                    35                                                203
# mean                   NaN                                                NaN
# std                    NaN                                                NaN
# min                    NaN                                                NaN
# 25%                    NaN                                                NaN
# 50%                    NaN                                                NaN
# 75%                    NaN                                                NaN
# max                    NaN                                                NaN

# %%
filtered_df = df[df['categories'].str.contains('Restaurant', case=False, na=False)]

# Display the resulting DataFrame
filtered_df
# Out:
#                  business_id                                name  \
# 0     Apn5Q_b6Nz61Tq4XzPdf9A                Minhas Micro Brewery
# 1     AjEbIBw6ZFfln7ePHha9PA                 CK'S BBQ & Catering
# 2     O8S5hYJ1SMc8fA4QBtVujA                       La Bastringue
# 7     6OuOZAok8ikONMS_T3EzXg                         Thai One On
# 8     8-NRKkPY1UiFXW20WXKiXg            Filiberto's Mexican Food
# ...                      ...                                 ...
# 4992  rvnTFEq7R2ZHg0_CYbBNFw              Village Seafood Buffet
# 4996  ZQBUBnccfiCzQTrEwNy-xw  All American Dave's Fit Food Truck
# 4997  KxYpQHzuBlnAMmDlxrAoeA                 Long Creek Fish Fry
# 4998  ZeEKKLja4xeGuy2nApMpsw          Coney Island Fried Chicken
# 4999  SbS0cnxFStrlidtwek6b6w                                100℃
#
#                    neighborhood  \
# 0
# 1
# 2     Rosemont-La Petite-Patrie
# 7                     Ridgewood
# 8
# ...                         ...
# 4992
# 4996
# 4997
# 4998                 Unionville
# 4999                  Chinatown
#
#                                                 address         city state  \
# 0                                     1314 44 Avenue NE      Calgary    AB
# 1                                                          Henderson    NV
# 2                                   1335 rue Beaubien E     Montréal    QC
# 7                           3417 Derry Road E, Unit 103  Mississauga    ON
# 8                                    1440 N. Dysart Ave     Avondale    AZ
# ...                                                 ...          ...   ...
# 4992  Rio All-Suite Hotel & Casino, 3700 W. Flamingo...    Las Vegas    NV
# 4996                                   4291 Polaris Ave    Las Vegas    NV
# 4997                               1031 Lower Dallas Rd       Dallas    NC
# 4998                                   5261 Highway 7 E      Markham    ON
# 4999                     5600 Spring Mountain Rd, Ste B    Las Vegas    NV
#
#      postal_code   latitude   longitude  stars  review_count  is_open  \
# 0        T2E 6L6  51.091813 -114.031675    4.0            24        1
# 1          89002  35.960734 -114.939821    4.5             3        0
# 2        H2G 1K7  45.540503  -73.599300    4.0             5        0
# 7        L4T 1A8  43.712946  -79.632763    2.0             7        1
# 8          85323  33.448106 -112.341302    2.5            40        1
# ...          ...        ...         ...    ...           ...      ...
# 4992       89103  36.118117 -115.187298    3.5           820        0
# 4996       89103  36.107558 -115.181217    4.5             9        1
# 4997       28034  35.312525  -81.157819    4.0             4        1
# 4998     L3P 1B8  43.866732  -79.283908    3.5             9        0
# 4999       89146  36.126508 -115.218285    4.0            46        0
#
#                                              attributes  \
# 0     {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1     {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2     {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 7     {'Alcohol': 'none', 'BusinessAcceptsCreditCard...
# 8     {'Alcohol': 'none', 'Ambience': '{'romantic': ...
# ...                                                 ...
# 4992  {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 4996  {'Alcohol': 'none', 'BikeParking': 'True', 'Bu...
# 4997                                               None
# 4998  {'Alcohol': 'none', 'Ambience': '{'romantic': ...
# 4999  {'Alcohol': 'none', 'Ambience': '{'romantic': ...
#
#                                              categories  \
# 0     Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1     Chicken Wings, Burgers, Caterers, Street Vendo...
# 2     Breakfast & Brunch, Restaurants, French, Sandw...
# 7                                     Restaurants, Thai
# 8                                  Mexican, Restaurants
# ...                                                 ...
# 4992                      Restaurants, Buffets, Seafood
# 4996  Restaurants, Food Trucks, Health & Medical, Gl...
# 4997                               Seafood, Restaurants
# 4998        Food, Restaurants, Fast Food, Chicken Wings
# 4999           Chinese, Taiwanese, Restaurants, Hot Pot
#
#                                                   hours
# 0     {'Monday': '8:30-17:0', 'Tuesday': '11:0-21:0'...
# 1     {'Friday': '17:0-23:0', 'Saturday': '17:0-23:0...
# 2     {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...
# 7                                                  None
# 8     {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# ...                                                 ...
# 4992  {'Monday': '15:30-21:30', 'Tuesday': '15:30-21...
# 4996  {'Monday': '9:0-23:0', 'Tuesday': '9:0-23:0', ...
# 4997  {'Wednesday': '15:0-21:0', 'Thursday': '15:0-2...
# 4998  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 4999  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
#
# [1556 rows x 15 columns]

# %%
print(filtered_df['attributes'])
# Out:
# 0       {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1       {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2       {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 7       {'Alcohol': 'none', 'BusinessAcceptsCreditCard...
# 8       {'Alcohol': 'none', 'Ambience': '{'romantic': ...
#                               ...
# 4992    {'Alcohol': 'full_bar', 'Ambience': '{'romanti...
# 4996    {'Alcohol': 'none', 'BikeParking': 'True', 'Bu...
# 4997                                                 None
# 4998    {'Alcohol': 'none', 'Ambience': '{'romantic': ...
# 4999    {'Alcohol': 'none', 'Ambience': '{'romantic': ...
# Name: attributes, Length: 1556, dtype: object

# %%
import pandas as pd

# creates a copy of the dataframe
df_split_attributes = filtered_df.copy()

# makes sure the values are in dictionary format
df_split_attributes['attributes'] = df_split_attributes['attributes'].fillna({})

# make new columns for each attribute
for index, row in df_split_attributes.iterrows():
    attributes = row['attributes']
    if attributes is not None:
        for key, value in attributes.items():
            # Create a new column for each attribute key
            df_split_attributes.at[index, key] = value

# drops 'attributes' column
df_split_attributes = df_split_attributes.drop('attributes', axis=1)

df_split_attributes
# Out:
#                  business_id                                name  \
# 0     Apn5Q_b6Nz61Tq4XzPdf9A                Minhas Micro Brewery
# 1     AjEbIBw6ZFfln7ePHha9PA                 CK'S BBQ & Catering
# 2     O8S5hYJ1SMc8fA4QBtVujA                       La Bastringue
# 7     6OuOZAok8ikONMS_T3EzXg                         Thai One On
# 8     8-NRKkPY1UiFXW20WXKiXg            Filiberto's Mexican Food
# ...                      ...                                 ...
# 4992  rvnTFEq7R2ZHg0_CYbBNFw              Village Seafood Buffet
# 4996  ZQBUBnccfiCzQTrEwNy-xw  All American Dave's Fit Food Truck
# 4997  KxYpQHzuBlnAMmDlxrAoeA                 Long Creek Fish Fry
# 4998  ZeEKKLja4xeGuy2nApMpsw          Coney Island Fried Chicken
# 4999  SbS0cnxFStrlidtwek6b6w                                100℃
#
#                    neighborhood  \
# 0
# 1
# 2     Rosemont-La Petite-Patrie
# 7                     Ridgewood
# 8
# ...                         ...
# 4992
# 4996
# 4997
# 4998                 Unionville
# 4999                  Chinatown
#
#                                                 address         city state  \
# 0                                     1314 44 Avenue NE      Calgary    AB
# 1                                                          Henderson    NV
# 2                                   1335 rue Beaubien E     Montréal    QC
# 7                           3417 Derry Road E, Unit 103  Mississauga    ON
# 8                                    1440 N. Dysart Ave     Avondale    AZ
# ...                                                 ...          ...   ...
# 4992  Rio All-Suite Hotel & Casino, 3700 W. Flamingo...    Las Vegas    NV
# 4996                                   4291 Polaris Ave    Las Vegas    NV
# 4997                               1031 Lower Dallas Rd       Dallas    NC
# 4998                                   5261 Highway 7 E      Markham    ON
# 4999                     5600 Spring Mountain Rd, Ste B    Las Vegas    NV
#
#      postal_code   latitude   longitude  stars  ...  Corkage  GoodForDancing  \
# 0        T2E 6L6  51.091813 -114.031675    4.0  ...      NaN             NaN
# 1          89002  35.960734 -114.939821    4.5  ...      NaN             NaN
# 2        H2G 1K7  45.540503  -73.599300    4.0  ...      NaN             NaN
# 7        L4T 1A8  43.712946  -79.632763    2.0  ...      NaN             NaN
# 8          85323  33.448106 -112.341302    2.5  ...      NaN             NaN
# ...          ...        ...         ...    ...  ...      ...             ...
# 4992       89103  36.118117 -115.187298    3.5  ...      NaN             NaN
# 4996       89103  36.107558 -115.181217    4.5  ...      NaN             NaN
# 4997       28034  35.312525  -81.157819    4.0  ...      NaN             NaN
# 4998     L3P 1B8  43.866732  -79.283908    3.5  ...      NaN             NaN
# 4999       89146  36.126508 -115.218285    4.0  ...      NaN             NaN
#
#      HappyHour Music Smoking ByAppointmentOnly RestaurantsCounterService  \
# 0          NaN   NaN     NaN               NaN                       NaN
# 1          NaN   NaN     NaN               NaN                       NaN
# 2          NaN   NaN     NaN               NaN                       NaN
# 7          NaN   NaN     NaN               NaN                       NaN
# 8          NaN   NaN     NaN               NaN                       NaN
# ...        ...   ...     ...               ...                       ...
# 4992       NaN   NaN     NaN               NaN                     False
# 4996       NaN   NaN     NaN               NaN                       NaN
# 4997       NaN   NaN     NaN               NaN                       NaN
# 4998       NaN   NaN     NaN               NaN                       NaN
# 4999       NaN   NaN     NaN               NaN                       NaN
#
#      BusinessAcceptsBitcoin Open24Hours AcceptsInsurance
# 0                       NaN         NaN              NaN
# 1                       NaN         NaN              NaN
# 2                       NaN         NaN              NaN
# 7                       NaN         NaN              NaN
# 8                       NaN         NaN              NaN
# ...                     ...         ...              ...
# 4992                    NaN         NaN              NaN
# 4996                   True         NaN              NaN
# 4997                    NaN         NaN              NaN
# 4998                    NaN         NaN              NaN
# 4999                    NaN         NaN              NaN
#
# [1556 rows x 50 columns]

# %%
null_counts = df_split_attributes.isnull().sum()
#shows the amount of nulls in each column

print(null_counts)
# Out:
# business_id                      0
# name                             0
# neighborhood                     0
# address                          0
# city                             0
# state                            0
# postal_code                      0
# latitude                         0
# longitude                        0
# stars                            0
# review_count                     0
# is_open                          0
# categories                       0
# hours                          386
# BikeParking                    501
# BusinessAcceptsCreditCards     248
# BusinessParking                286
# GoodForKids                    218
# HasTV                          351
# NoiseLevel                     458
# OutdoorSeating                 267
# RestaurantsAttire              253
# RestaurantsDelivery            218
# RestaurantsGoodForGroups       197
# RestaurantsPriceRange2         161
# RestaurantsReservations        215
# RestaurantsTakeOut             158
# Alcohol                        384
# Caters                         635
# DogsAllowed                   1345
# DriveThru                     1367
# GoodForMeal                    286
# RestaurantsTableService        389
# WheelchairAccessible           934
# WiFi                           491
# Ambience                       355
# BYOB                          1530
# BYOBCorkage                   1517
# BestNights                    1440
# CoatCheck                     1406
# Corkage                       1538
# GoodForDancing                1396
# HappyHour                     1392
# Music                         1407
# Smoking                       1419
# ByAppointmentOnly             1546
# RestaurantsCounterService     1542
# BusinessAcceptsBitcoin        1488
# Open24Hours                   1548
# AcceptsInsurance              1555
# dtype: int64

# %%
attributes_to_avg_stars = [
    'BikeParking', 'BusinessAcceptsCreditCards', 'BusinessParking', 'GoodForKids', 'HasTV',
    'NoiseLevel', 'OutdoorSeating', 'RestaurantsAttire', 'RestaurantsDelivery', 'RestaurantsGoodForGroups',
    'RestaurantsPriceRange2', 'RestaurantsReservations', 'RestaurantsTakeOut', 'Alcohol', 'Caters', 'DogsAllowed',
    'DriveThru', 'GoodForMeal', 'RestaurantsTableService', 'WheelchairAccessible', 'WiFi', 'Ambience', 'BYOB',
    'BYOBCorkage', 'BestNights', 'CoatCheck', 'Corkage', 'GoodForDancing', 'HappyHour', 'Music', 'Smoking',
    'ByAppointmentOnly', 'RestaurantsCounterService', 'BusinessAcceptsBitcoin', 'Open24Hours', 'AcceptsInsurance'
]
#performing this code because we need to find how impactful each attribute is to the star rating
for attribute in attributes_to_avg_stars:
    avg_stars = df_split_attributes.groupby(attribute)["stars"].mean()
    print(f"Average stars for {attribute}:\n{avg_stars}\n")
# Out:
# Average stars for BikeParking:
# BikeParking
# False    3.448617
# True     3.543641
# Name: stars, dtype: float64
#
# Average stars for BusinessAcceptsCreditCards:
# BusinessAcceptsCreditCards
# False    3.650000
# True     3.415064
# Name: stars, dtype: float64
#
# Average stars for BusinessParking:
# BusinessParking
# {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}    3.369608
# {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': True}     3.500000
# {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}     3.520142
# {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': True}      3.200000
# {'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}     3.664502
# {'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': True}      3.900000
# {'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}      3.718750
# {'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}     3.600000
# {'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}      3.750000
# {'garage': True, 'street': False, 'validated': False, 'lot': True, 'valet': False}      3.700000
# {'garage': True, 'street': False, 'validated': False, 'lot': True, 'valet': True}       3.750000
# {'garage': True, 'street': False, 'validated': True, 'lot': False, 'valet': False}      3.000000
# {'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}      3.928571
# {'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': True}       3.500000
# {'garage': True, 'street': True, 'validated': False, 'lot': True, 'valet': False}       3.000000
# {'garage': True, 'street': True, 'validated': False, 'lot': True, 'valet': True}        4.000000
# {'garage': True, 'street': True, 'validated': True, 'lot': True, 'valet': True}         3.000000
# Name: stars, dtype: float64
#
# Average stars for GoodForKids:
# GoodForKids
# False    3.457746
# True     3.434222
# Name: stars, dtype: float64
#
# Average stars for HasTV:
# HasTV
# False    3.430833
# True     3.496694
# Name: stars, dtype: float64
#
# Average stars for NoiseLevel:
# NoiseLevel
# average      3.496503
# loud         3.230337
# quiet        3.572289
# very_loud    2.833333
# Name: stars, dtype: float64
#
# Average stars for OutdoorSeating:
# OutdoorSeating
# False    3.417901
# True     3.561587
# Name: stars, dtype: float64
#
# Average stars for RestaurantsAttire:
# RestaurantsAttire
# casual    3.429873
# dressy    3.631579
# formal    3.000000
# Name: stars, dtype: float64
#
# Average stars for RestaurantsDelivery:
# RestaurantsDelivery
# False    3.466731
# True     3.382060
# Name: stars, dtype: float64
#
# Average stars for RestaurantsGoodForGroups:
# RestaurantsGoodForGroups
# False    3.355856
# True     3.450748
# Name: stars, dtype: float64
#
# Average stars for RestaurantsPriceRange2:
# RestaurantsPriceRange2
# 1    3.423077
# 2    3.463092
# 3    3.582418
# 4    3.571429
# Name: stars, dtype: float64
#
# Average stars for RestaurantsReservations:
# RestaurantsReservations
# False    3.372430
# True     3.570039
# Name: stars, dtype: float64
#
# Average stars for RestaurantsTakeOut:
# RestaurantsTakeOut
# False    3.572917
# True     3.433564
# Name: stars, dtype: float64
#
# Average stars for Alcohol:
# Alcohol
# beer_and_wine    3.622581
# full_bar         3.512644
# none             3.389175
# Name: stars, dtype: float64
#
# Average stars for Caters:
# Caters
# False    3.308756
# True     3.623203
# Name: stars, dtype: float64
#
# Average stars for DogsAllowed:
# DogsAllowed
# False    3.658824
# True     3.792683
# Name: stars, dtype: float64
#
# Average stars for DriveThru:
# DriveThru
# False    3.330357
# True     2.532468
# Name: stars, dtype: float64
#
# Average stars for GoodForMeal:
# GoodForMeal
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': False}    3.331967
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': True}     3.894737
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': False}     3.222222
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': True}      3.304348
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': False}     3.600000
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': True}      3.900000
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': False}     3.420732
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': True}      4.038462
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': False}      3.812500
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': True}       3.704545
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': False}      3.619318
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': True}       3.863636
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': False}       3.250000
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': True}        3.666667
# {'dessert': False, 'latenight': True, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': False}     3.366667
# {'dessert': False, 'latenight': True, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': True}      3.000000
# {'dessert': False, 'latenight': True, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': False}      3.611111
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': False}      2.625000
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': False}       3.000000
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': True}        3.000000
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': False}       3.523810
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': True}        4.000000
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': False}        3.125000
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': True}         4.000000
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': False}     3.750000
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': True}      3.000000
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': False}      3.000000
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': True}       3.250000
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': False}      4.000000
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': False}      2.700000
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': True}       3.750000
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': True}        3.666667
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': False}       3.500000
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': True}        4.500000
# {'dessert': True, 'latenight': True, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': False}      2.000000
# {'dessert': True, 'latenight': True, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': False}       4.000000
# {'dessert': True, 'latenight': True, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': True}         2.500000
# {'dessert': True, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': False}         2.500000
# {'dessert': True, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': True}          3.500000
# Name: stars, dtype: float64
#
# Average stars for RestaurantsTableService:
# RestaurantsTableService
# False    3.363043
# True     3.541018
# Name: stars, dtype: float64
#
# Average stars for WheelchairAccessible:
# WheelchairAccessible
# False    3.586420
# True     3.584104
# Name: stars, dtype: float64
#
# Average stars for WiFi:
# WiFi
# free    3.574194
# no      3.415254
# paid    3.200000
# Name: stars, dtype: float64
#
# Average stars for Ambience:
# Ambience
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}    3.217544
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}     3.558209
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': True, 'casual': True}      3.500000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}     3.375000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}      4.055556
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': True, 'casual': False}      3.750000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': True, 'trendy': False, 'upscale': False, 'casual': False}     2.750000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': True, 'trendy': False, 'upscale': False, 'casual': True}      3.500000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': True, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}     3.575000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': True, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}      3.562500
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                    3.443182
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}                     3.531792
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': True, 'casual': False}                     3.500000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}                     3.625000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}                      3.625000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': True, 'trendy': False, 'upscale': False, 'casual': True}                      3.000000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}     4.166667
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}      4.166667
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}      4.000000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}       4.500000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                     3.625000
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}                      3.833333
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}     3.687500
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': True, 'casual': False}      3.500000
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}      4.000000
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}       2.500000
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': True, 'casual': False}       4.000000
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                     3.611111
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'touristy': False, 'trendy': True, 'upscale': True, 'casual': False}                       3.750000
# {'romantic': False, 'intimate': False, 'touristy': False, 'upscale': False, 'classy': False, 'trendy': False, 'casual': False}                                      3.500000
# {'romantic': False, 'intimate': True, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}     4.250000
# {'romantic': False, 'intimate': True, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                     3.700000
# {'romantic': False, 'intimate': True, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}                       5.000000
# {'romantic': False, 'intimate': True, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}      4.000000
# {'romantic': False, 'intimate': True, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}        4.500000
# {'romantic': False, 'intimate': True, 'classy': True, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                      4.500000
# {'romantic': True, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}     4.000000
# {'romantic': True, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': True, 'casual': True}       4.000000
# {'romantic': True, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                     4.000000
# {'romantic': True, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}       3.500000
# {'romantic': True, 'intimate': False, 'classy': True, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                      4.000000
# {'romantic': True, 'intimate': True, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}      4.000000
# {'romantic': True, 'intimate': True, 'classy': True, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}          4.500000
# Name: stars, dtype: float64
#
# Average stars for BYOB:
# BYOB
# False    3.58
# True     3.50
# Name: stars, dtype: float64
#
# Average stars for BYOBCorkage:
# BYOBCorkage
# no             3.657895
# yes_corkage    3.750000
# yes_free       3.531250
# Name: stars, dtype: float64
#
# Average stars for BestNights:
# BestNights
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}    3.000000
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}     2.900000
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': False}     3.250000
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': True}      3.500000
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': False}     3.000000
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': True, 'saturday': True}       3.166667
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': False}     2.500000
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': True, 'sunday': False, 'saturday': True}       3.125000
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}     3.550000
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}      3.666667
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': True}       3.566667
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': True}       3.656250
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': True}       3.875000
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': True, 'thursday': False, 'sunday': True, 'saturday': False}       4.000000
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': True, 'thursday': True, 'sunday': False, 'saturday': False}       4.250000
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}     3.250000
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': True, 'thursday': True, 'sunday': False, 'saturday': False}       2.500000
# {'monday': False, 'tuesday': True, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}      3.000000
# {'monday': False, 'tuesday': True, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}       3.700000
# {'monday': False, 'tuesday': True, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': False}       4.000000
# {'monday': False, 'tuesday': True, 'friday': True, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': False}       3.500000
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': False}      3.500000
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': True}       3.500000
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': True}       2.500000
# {'monday': True, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}       3.625000
# {'monday': True, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': False}       3.000000
# {'monday': True, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': False}       3.500000
# {'monday': True, 'tuesday': False, 'friday': True, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': False}       4.000000
# {'monday': True, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}       2.500000
# {'monday': True, 'tuesday': True, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': False}       3.250000
# Name: stars, dtype: float64
#
# Average stars for CoatCheck:
# CoatCheck
# False    3.451493
# True     3.625000
# Name: stars, dtype: float64
#
# Average stars for Corkage:
# Corkage
# False    3.53125
# True     4.00000
# Name: stars, dtype: float64
#
# Average stars for GoodForDancing:
# GoodForDancing
# False    3.45
# True     3.45
# Name: stars, dtype: float64
#
# Average stars for HappyHour:
# HappyHour
# False    3.360000
# True     3.489209
# Name: stars, dtype: float64
#
# Average stars for Music:
# Music
# {'dj': False, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': False}    3.388889
# {'dj': False, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': True}     3.357143
# {'dj': False, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': True, 'video': False, 'jukebox': False}     3.631579
# {'dj': False, 'background_music': False, 'no_music': False, 'karaoke': True, 'live': False, 'video': False, 'jukebox': False}     3.500000
# {'dj': False, 'background_music': True, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': False}     3.557692
# {'dj': False, 'background_music': True, 'no_music': False, 'karaoke': False, 'live': True, 'video': False, 'jukebox': False}      3.250000
# {'dj': False, 'background_music': True, 'no_music': False, 'karaoke': True, 'live': False, 'video': False, 'jukebox': False}      4.000000
# {'dj': True, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': False}     3.600000
# {'dj': True, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': True}      2.750000
# {'dj': True, 'background_music': True, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': False}      2.500000
# {'dj': True, 'background_music': True, 'no_music': False, 'karaoke': False, 'live': True, 'video': False, 'jukebox': False}       4.000000
# Name: stars, dtype: float64
#
# Average stars for Smoking:
# Smoking
# no         3.600000
# outdoor    3.459016
# yes        3.681818
# Name: stars, dtype: float64
#
# Average stars for ByAppointmentOnly:
# ByAppointmentOnly
# False    4.0
# True     3.5
# Name: stars, dtype: float64
#
# Average stars for RestaurantsCounterService:
# RestaurantsCounterService
# False    3.428571
# True     3.714286
# Name: stars, dtype: float64
#
# Average stars for BusinessAcceptsBitcoin:
# BusinessAcceptsBitcoin
# False    3.769231
# True     4.166667
# Name: stars, dtype: float64
#
# Average stars for Open24Hours:
# Open24Hours
# False    3.785714
# True     2.500000
# Name: stars, dtype: float64
#
# Average stars for AcceptsInsurance:
# AcceptsInsurance
# False    3.5
# Name: stars, dtype: float64

# %%
correlation_matrix = df_split_attributes.corrwith(df_split_attributes['stars'])

# Display the correlation matrix
print(correlation_matrix)
# Out:
# C:\Users\adam\AppData\Local\Temp\ipykernel_8600\1128902249.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_split_attributes.corrwith(df_split_attributes['stars'])
# latitude        0.046082
# longitude       0.033903
# stars           1.000000
# review_count    0.151290
# is_open         0.017406
# dtype: float64

# %%
# check for nulls in these columns
columns_to_check = ['NoiseLevel', 'RestaurantsAttire', 'Caters']

#creates a new dataframe without nulls in these columns
df_filtered2 = df_split_attributes.dropna(subset=columns_to_check).copy()
df_filtered2 = df_filtered2.dropna(axis=1)

df_filtered2.head()
# Out:
#                business_id                        name  \
# 2   O8S5hYJ1SMc8fA4QBtVujA               La Bastringue
# 8   8-NRKkPY1UiFXW20WXKiXg    Filiberto's Mexican Food
# 11  tZnSodhPwNr4bzrwJ1CSbw  Southern Accent Restaurant
# 12  _c3ixq9jYKxhLUB0czi0ug    Original Hamburger Works
# 16  r89Re4FNgVWHgBfjCVZyVw                      Harlow
#
#                  neighborhood                    address      city state  \
# 2   Rosemont-La Petite-Patrie        1335 rue Beaubien E  Montréal    QC
# 8                                     1440 N. Dysart Ave  Avondale    AZ
# 11                 Palmerston         595 Markham Street   Toronto    ON
# 12                                       2801 N 15th Ave   Phoenix    AZ
# 16                Ville-Marie  438 Place Jacques Cartier  Montréal    QC
#
#    postal_code   latitude   longitude  stars  review_count  is_open  \
# 2      H2G 1K7  45.540503  -73.599300    4.0             5        0
# 8        85323  33.448106 -112.341302    2.5            40        1
# 11     M6G 2L7  43.664125  -79.411886    4.0           146        0
# 12       85007  33.479807 -112.091188    4.0           277        1
# 16     H2Y 3B3  45.507699  -73.553407    3.5            12        0
#
#                                            categories NoiseLevel  \
# 2   Breakfast & Brunch, Restaurants, French, Sandw...    average
# 8                                Mexican, Restaurants    average
# 11                Cajun/Creole, Southern, Restaurants    average
# 12  Bars, Sports Bars, Dive Bars, Burgers, Nightli...    average
# 16  Nightlife, Bars, American (Traditional), Tapas...    average
#
#    RestaurantsAttire Caters
# 2             casual  False
# 8             casual  False
# 11            casual   True
# 12            casual  False
# 16            dressy  False

# %%
# replaces each categorical value with a numerical one
cater_mapping = {'False': 0, 'True': 1}
df_filtered2['Caters'] = df_filtered2['Caters'].replace(cater_mapping)

noise_level_mapping = {'quiet': 3, 'average': 2, 'loud': 1, 'very_loud': 0}
df_filtered2['NoiseLevel'] = df_filtered2['NoiseLevel'].replace(noise_level_mapping)

attire_mapping = {'formal': 0, 'casual': 1, 'dressy': 2}
df_filtered2['RestaurantsAttire'] = df_filtered2['RestaurantsAttire'].replace(attire_mapping)

df_filtered2
# Out:
#                  business_id                        name  \
# 2     O8S5hYJ1SMc8fA4QBtVujA               La Bastringue
# 8     8-NRKkPY1UiFXW20WXKiXg    Filiberto's Mexican Food
# 11    tZnSodhPwNr4bzrwJ1CSbw  Southern Accent Restaurant
# 12    _c3ixq9jYKxhLUB0czi0ug    Original Hamburger Works
# 16    r89Re4FNgVWHgBfjCVZyVw                      Harlow
# ...                      ...                         ...
# 4986  VVUL1lzBOipXJlOG1wURMg     Tangerine Asian Cuisine
# 4990  nG59soBP2SaQ25rf2n-0bA               Atlanta Bread
# 4992  rvnTFEq7R2ZHg0_CYbBNFw      Village Seafood Buffet
# 4998  ZeEKKLja4xeGuy2nApMpsw  Coney Island Fried Chicken
# 4999  SbS0cnxFStrlidtwek6b6w                        100℃
#
#                    neighborhood  \
# 2     Rosemont-La Petite-Patrie
# 8
# 11                   Palmerston
# 12
# 16                  Ville-Marie
# ...                         ...
# 4986
# 4990
# 4992
# 4998                 Unionville
# 4999                  Chinatown
#
#                                                 address       city state  \
# 2                                   1335 rue Beaubien E   Montréal    QC
# 8                                    1440 N. Dysart Ave   Avondale    AZ
# 11                                   595 Markham Street    Toronto    ON
# 12                                      2801 N 15th Ave    Phoenix    AZ
# 16                            438 Place Jacques Cartier   Montréal    QC
# ...                                                 ...        ...   ...
# 4986                           7690 Markham Rd, Unit 4C    Markham    ON
# 4990                                     1905 S Neil St  Champaign    IL
# 4992  Rio All-Suite Hotel & Casino, 3700 W. Flamingo...  Las Vegas    NV
# 4998                                   5261 Highway 7 E    Markham    ON
# 4999                     5600 Spring Mountain Rd, Ste B  Las Vegas    NV
#
#      postal_code   latitude   longitude  stars  review_count  is_open  \
# 2        H2G 1K7  45.540503  -73.599300    4.0             5        0
# 8          85323  33.448106 -112.341302    2.5            40        1
# 11       M6G 2L7  43.664125  -79.411886    4.0           146        0
# 12         85007  33.479807 -112.091188    4.0           277        1
# 16       H2Y 3B3  45.507699  -73.553407    3.5            12        0
# ...          ...        ...         ...    ...           ...      ...
# 4986     L3S 3S1  43.852986  -79.255643    3.5            82        1
# 4990       61820  40.092944  -88.245995    3.0            43        0
# 4992       89103  36.118117 -115.187298    3.5           820        0
# 4998     L3P 1B8  43.866732  -79.283908    3.5             9        0
# 4999       89146  36.126508 -115.218285    4.0            46        0
#
#                                              categories  NoiseLevel  \
# 2     Breakfast & Brunch, Restaurants, French, Sandw...           2
# 8                                  Mexican, Restaurants           2
# 11                  Cajun/Creole, Southern, Restaurants           2
# 12    Bars, Sports Bars, Dive Bars, Burgers, Nightli...           2
# 16    Nightlife, Bars, American (Traditional), Tapas...           2
# ...                                                 ...         ...
# 4986                               Restaurants, Chinese           2
# 4990  Bakeries, Food, Restaurants, Cafes, Sandwiches...           2
# 4992                      Restaurants, Buffets, Seafood           2
# 4998        Food, Restaurants, Fast Food, Chicken Wings           0
# 4999           Chinese, Taiwanese, Restaurants, Hot Pot           3
#
#       RestaurantsAttire  Caters
# 2                     1       0
# 8                     1       0
# 11                    1       1
# 12                    1       0
# 16                    2       0
# ...                 ...     ...
# 4986                  1       1
# 4990                  1       1
# 4992                  1       0
# 4998                  1       0
# 4999                  1       1
#
# [836 rows x 16 columns]

# %%
df_model = df_filtered2[['business_id', 'stars', 'name', 'NoiseLevel', 'review_count', 'RestaurantsAttire', 'Caters']].copy()

df_model
# Out:
#                  business_id  stars                        name  NoiseLevel  \
# 2     O8S5hYJ1SMc8fA4QBtVujA    4.0               La Bastringue           2
# 8     8-NRKkPY1UiFXW20WXKiXg    2.5    Filiberto's Mexican Food           2
# 11    tZnSodhPwNr4bzrwJ1CSbw    4.0  Southern Accent Restaurant           2
# 12    _c3ixq9jYKxhLUB0czi0ug    4.0    Original Hamburger Works           2
# 16    r89Re4FNgVWHgBfjCVZyVw    3.5                      Harlow           2
# ...                      ...    ...                         ...         ...
# 4986  VVUL1lzBOipXJlOG1wURMg    3.5     Tangerine Asian Cuisine           2
# 4990  nG59soBP2SaQ25rf2n-0bA    3.0               Atlanta Bread           2
# 4992  rvnTFEq7R2ZHg0_CYbBNFw    3.5      Village Seafood Buffet           2
# 4998  ZeEKKLja4xeGuy2nApMpsw    3.5  Coney Island Fried Chicken           0
# 4999  SbS0cnxFStrlidtwek6b6w    4.0                        100℃           3
#
#       review_count  RestaurantsAttire  Caters
# 2                5                  1       0
# 8               40                  1       0
# 11             146                  1       1
# 12             277                  1       0
# 16              12                  2       0
# ...            ...                ...     ...
# 4986            82                  1       1
# 4990            43                  1       1
# 4992           820                  1       0
# 4998             9                  1       0
# 4999            46                  1       1
#
# [836 rows x 7 columns]

# %% [markdown]
# # The Solution: implement a data science solution to the problem you are trying to solve.

# %% [markdown]
# Briefly describe the idea of your solution to the problem in the following cell:

# %% [markdown]
# I will create  a linear regression and neural network model. Star rating could be seen as a categorical value where the are only a set amount of choices between 1-5 but I want to get a continous value for better accuracy. I decided to use review count, noise level, restaurant attire, and caters as features because they were present in most of the rows and they have a reasonably high correlation to the star level.

# %% [markdown]
# Write codes to implement the solution in python:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# put the features as the x value and the dependent varable as the y
x = df_model[['review_count', 'NoiseLevel', 'RestaurantsAttire', 'Caters']]
y = df_model['stars']

# normalize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)
# training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# linear regression model
linear_model = LinearRegression()

linear_model.fit(X_train, y_train)

y_pred = linear_model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"MSE: {mse}")
# Out:
# MSE: 0.4829965493982843

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x = df_model[['review_count', 'NoiseLevel', 'RestaurantsAttire', 'Caters']]
y = df_model['stars']

# Normalize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# learning rate
custom_learning_rate = 0.003  # Set your desired learning rate

# neural network model
model = Sequential()
model.add(Dense(64, activation='tanh', input_dim=X_train.shape[1]))
model.add(Dropout(0.5))
model.add(Dense(32, activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(16, activation='tanh'))
model.add(Dense(1, activation='linear'))

# customize the optimizer with the learning rate
custom_optimizer = RMSprop(learning_rate=custom_learning_rate)

# compile the model
model.compile(optimizer=custom_optimizer, loss='mean_squared_error')

# train the model
model.fit(X_train, y_train, epochs=75, batch_size=32, validation_split=0.2)

# evaluate the model
mse = model.evaluate(X_test, y_test)
print(f"MSE: {mse}")
# Out:
# WARNING:tensorflow:From C:\Users\adam\AppData\Roaming\Python\Python310\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\adam\AppData\Roaming\Python\Python310\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/75
# WARNING:tensorflow:From C:\Users\adam\AppData\Roaming\Python\Python310\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 17/17 [==============================] - 1s 14ms/step - loss: 6.7676 - val_loss: 1.4830
# Epoch 2/75
# 17/17 [==============================] - 0s 5ms/step - loss: 1.7206 - val_loss: 1.0631
# Epoch 3/75
# 17/17 [==============================] - 0s 4ms/step - loss: 1.1189 - val_loss: 0.6103
# Epoch 4/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.8531 - val_loss: 0.5818
# Epoch 5/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6718 - val_loss: 0.5058
# Epoch 6/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6084 - val_loss: 0.3945
# Epoch 7/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5936 - val_loss: 0.3854
# Epoch 8/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4826 - val_loss: 0.4028
# Epoch 9/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5203 - val_loss: 0.3893
# Epoch 10/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5044 - val_loss: 0.3887
# Epoch 11/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4535 - val_loss: 0.3837
# Epoch 12/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4826 - val_loss: 0.3787
# Epoch 13/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4624 - val_loss: 0.3956
# Epoch 14/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4473 - val_loss: 0.3955
# Epoch 15/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4543 - val_loss: 0.3828
# Epoch 16/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4542 - val_loss: 0.4074
# Epoch 17/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4395 - val_loss: 0.3838
# Epoch 18/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4316 - val_loss: 0.3801
# Epoch 19/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4663 - val_loss: 0.3849
# Epoch 20/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4340 - val_loss: 0.3816
# Epoch 21/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4432 - val_loss: 0.3807
# Epoch 22/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4223 - val_loss: 0.3803
# Epoch 23/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4255 - val_loss: 0.3818
# Epoch 24/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4310 - val_loss: 0.4075
# Epoch 25/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4251 - val_loss: 0.3875
# Epoch 26/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4269 - val_loss: 0.3805
# Epoch 27/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4220 - val_loss: 0.3825
# Epoch 28/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4381 - val_loss: 0.3760
# Epoch 29/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4479 - val_loss: 0.3813
# Epoch 30/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4411 - val_loss: 0.3830
# Epoch 31/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4385 - val_loss: 0.3743
# Epoch 32/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4324 - val_loss: 0.3774
# Epoch 33/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4269 - val_loss: 0.3741
# Epoch 34/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4588 - val_loss: 0.3775
# Epoch 35/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4195 - val_loss: 0.3848
# Epoch 36/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4295 - val_loss: 0.3739
# Epoch 37/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4304 - val_loss: 0.3832
# Epoch 38/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4383 - val_loss: 0.3761
# Epoch 39/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4295 - val_loss: 0.3837
# Epoch 40/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4303 - val_loss: 0.3809
# Epoch 41/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4327 - val_loss: 0.3743
# Epoch 42/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4143 - val_loss: 0.3792
# Epoch 43/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4489 - val_loss: 0.4036
# Epoch 44/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4282 - val_loss: 0.3790
# Epoch 45/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4255 - val_loss: 0.3756
# Epoch 46/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4192 - val_loss: 0.3753
# Epoch 47/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4278 - val_loss: 0.3917
# Epoch 48/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4172 - val_loss: 0.3772
# Epoch 49/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4081 - val_loss: 0.3736
# Epoch 50/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4176 - val_loss: 0.4065
# Epoch 51/75
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4043 - val_loss: 0.3754
# Epoch 52/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4381 - val_loss: 0.3767
# Epoch 53/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4147 - val_loss: 0.4002
# Epoch 54/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4154 - val_loss: 0.3895
# Epoch 55/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4816 - val_loss: 0.3772
# Epoch 56/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4295 - val_loss: 0.3755
# Epoch 57/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4164 - val_loss: 0.3788
# Epoch 58/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4211 - val_loss: 0.3903
# Epoch 59/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4340 - val_loss: 0.3940
# Epoch 60/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4150 - val_loss: 0.3794
# Epoch 61/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4326 - val_loss: 0.3922
# Epoch 62/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4144 - val_loss: 0.3910
# Epoch 63/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4191 - val_loss: 0.3867
# Epoch 64/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4108 - val_loss: 0.3824
# Epoch 65/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4135 - val_loss: 0.3868
# Epoch 66/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4213 - val_loss: 0.3780
# Epoch 67/75
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4112 - val_loss: 0.3806
# Epoch 68/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4179 - val_loss: 0.3788
# Epoch 69/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4063 - val_loss: 0.3819
# Epoch 70/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4134 - val_loss: 0.3816
# Epoch 71/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4306 - val_loss: 0.3785
# Epoch 72/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4206 - val_loss: 0.3822
# Epoch 73/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4125 - val_loss: 0.3795
# Epoch 74/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4216 - val_loss: 0.3879
# Epoch 75/75
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4579 - val_loss: 0.3781
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4670
# Mean Squared Error: 0.4670303761959076

# %% [markdown]
# # Results: summarize and visualize the results discovered from the analysis
#
# Please use figures or tables to present the results.

# %%
import matplotlib.pyplot as plt

# scatterplot of linear model actual vs predicted star ratings
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel('Actual Stars')
plt.ylabel('Predicted Stars')
plt.title('Linear Regression: Actual vs Predicted Stars')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

predictions = model.predict(X_test)

# scatterplot of the neural network actual vs predicted values
plt.scatter(y_test, predictions)
plt.xlabel('Actual Stars')
plt.ylabel('Predicted Stars')
plt.title('Neural Network Predictions')
plt.show()
# Out:
# 6/6 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt

predictions = model.predict(X_test)

predicted_values = predictions.flatten()
actual_values = y_test.values

# plot histograms
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(predicted_values, bins=30, color='blue', alpha=0.7)
plt.title('Histogram of Predicted Values')
plt.xlabel('Predicted Values')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(actual_values, bins=30, color='green', alpha=0.7)
plt.title('Histogram of Actual Values')
plt.xlabel('Actual Values')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# As you can see, the issue with the model is that it does not recognize when a restaurant will have very poor values or very good values. It tends to predict every value in the range of 3-4, meaning that the model predicted is slightly underfitting the data and playing it safe when predicting. This is unfortunate, however, as you can see the actual values lie in the 3-4 range much more than in the other ranges. This means that while the model might be poor at predicting extremes, it does do a good job at predicting a significant portion of businesses. The scatterplot shows how the model tends to overproject the low star restaurants and underprojects the high star restaurants but still puts each on the opposite side of the 3-4 range. This means that the model could give a solid rough estimate of what star rating a restaurant will have.

# %% [markdown]
# *-----------------
# # Done
#
# All set!
#
# ** What do you need to submit?**
#
# * **Notebook File**: Save this Jupyter notebook, and submit it in BrightSpace. Please make sure all the plotted tables and figures are in the notebook.
